# %%
Lsample = 3200*6.5/60#um
fobj = 200/60 #mm
fL1=75#mm
fL2=8#mm
ML1 = fL1/fobj
y2 = ML1*Lsample#um
y1=400#um -fiber size
y2/y1
# Out:
# 19.5

# %%
#Fiber<---x1--->L2<---D-75---->

# %%
#D-fL1 = x1*fL2/(x1+fL2)
#y2 = y1*fL2/(x1+fL2)

# %%
x1 = y1*fL2/y2-fL2
x2 = x1*fL2/(x1+fL2)
x2
# Out:
# -147.9999999999999

# %%
y1/y2
# Out:
# 0.0547008547008547

# %%
y2/y1
# Out:
# 18.28125

# %%
### COM3

# %%
16/(2800*0.108333)*5000
# Out:
# 263.73707523495676

# %%
WD = 0.15 (0.17 coverglass = 1.5)
